# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('election2024.csv')

# %%
data.sample(5)
# Out:
#                     id     sex   age federal_district  \
# 371   071664613fcce74c  female  80.0         siberian
# 1441  071686892b8ce0f9    male  49.0            volga
# 1435  0716c450c2cceeb9  female  39.0          central
# 1042  0716c411e00cec6a    male  33.0          central
# 60    071688d4680ce734    male  20.0         southern
#
#                           type_of_city knows_election_date       will_vote  \
# 371                            village  named correct date  definitely yes
# 1441  city with population of 100-500k  named correct date       likely no
# 1435   city with population of 50-100k  named correct date  definitely yes
# 1042  city with population of 100-500k  named correct date        not sure
# 60    city with population of 100-500k  named correct date  definitely yes
#
#                candidate         television_usage           internet_usage  \
# 371                Putin  less than 4 hours a day    does not use internet
# 1441  will not take part           does not watch  less than 4 hours a day
# 1435               Putin  less than 4 hours a day  less than 4 hours a day
# 1042               Putin           does not watch       over 4 hours a day
# 60                 Putin     several times a week       over 4 hours a day
#
#                         education  income            employment  \
# 371                       college    high  unemployed pensioner
# 1441                      college     low         work for hire
# 1435                      college     low         work for hire
# 1042              academic degree  medium         work for hire
# 60    incomplete school education    high         work for hire
#
#                      job_type  \
# 371                       NaN
# 1441  commercial organization
# 1435        government agency
# 1042  commercial organization
# 60                hard to say
#
#                                            company_type   weight1
# 371                                                 NaN  0.943955
# 1441                            industry, manufacturing  0.664523
# 1435                                    social services  0.975685
# 1042                                              trade  1.094328
# 60    Сфера услуг, сервиса, бытового обслуживания Вк...  0.978454

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   object
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  job_type             692 non-null    object
#  14  company_type         879 non-null    object
#  15  weight1              1600 non-null   float64
# dtypes: float64(2), object(14)
# memory usage: 200.1+ KB

# %%
data.shape
# Out:
# (1600, 16)

# %%
# Null values weightage
data.isna().sum() / len(data) * 100
# So it is better to drop job_type and company_type as they have manyy null values
# Out:
# id                      0.0000
# sex                     0.0000
# age                     0.0000
# federal_district        0.0000
# type_of_city            0.0000
# knows_election_date     0.0000
# will_vote               0.0000
# candidate               0.0000
# television_usage        0.0000
# internet_usage          0.0000
# education               0.0000
# income                  0.0000
# employment              0.0000
# job_type               56.7500
# company_type           45.0625
# weight1                 0.0000
# dtype: float64

# %%
data.drop('company_type', axis=1, inplace=True)
data.drop('job_type', axis=1, inplace=True)
data
# Out:
#                     id     sex   age federal_district  \
# 0     07169ed8148ce047    male  18.0  north caucasian
# 1     0716a4f3354cecdd    male  23.0  north caucasian
# 2     0716889b304ce79c    male  20.0            volga
# 3     07168e28b5cce563    male  22.0     northwestern
# 4     0716a563914ce549    male  21.0         southern
# ...                ...     ...   ...              ...
# 1595  0716b23c2c0cee3a    male  61.0          central
# 1596  07168254d14ceb55  female  80.0            volga
# 1597  071690f34d4ce164  female  76.0     northwestern
# 1598  0716bfa9c48ce79a  female  74.0          central
# 1599  07168088318cef88  female  76.0             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# 3     city with population of 1 million and higher  not sure or no answer
# 4     city with population of 1 million and higher     named correct date
# ...                                            ...                    ...
# 1595                                    settlement     named correct date
# 1596                                       village     named correct date
# 1597               city with population of 50-100k     named correct date
# 1598         city with population of less than 50k  not sure or no answer
# 1599                                       village     named correct date
#
#            will_vote           candidate      television_usage  \
# 0           not sure               Putin  several times a week
# 1           not sure               Putin      once half a year
# 2     definitely yes               Putin  several times a week
# 3           not sure            Davankov  several times a week
# 4     definitely yes               Putin        does not watch
# ...              ...                 ...                   ...
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# 1597  definitely yes               Putin        does not watch
# 1598  definitely yes               Putin    over 4 hours a day
# 1599  definitely yes               Putin    over 4 hours a day
#
#                internet_usage                    education       income  \
# 0          over 4 hours a day  incomplete school education    very high
# 1          over 4 hours a day                      college    very high
# 2          over 4 hours a day                      college    very high
# 3          over 4 hours a day                      college    very high
# 4          over 4 hours a day              bachelor degree    very high
# ...                       ...                          ...          ...
# 1595  less than 4 hours a day              bachelor degree  hard to say
# 1596    does not use internet                      college  hard to say
# 1597       over 4 hours a day              bachelor degree  hard to say
# 1598       over 4 hours a day              academic degree  hard to say
# 1599       over 4 hours a day                       school  hard to say
#
#                 employment   weight1
# 0             entrepreneur  1.445172
# 1            work for hire  1.445172
# 2            work for hire  1.301691
# 3               unemployed  1.538628
# 4         employed student  1.967015
# ...                    ...       ...
# 1595  unemployed pensioner  1.270761
# 1596  unemployed pensioner  0.921724
# 1597  unemployed pensioner  1.396691
# 1598    employed pensioner  0.995849
# 1599  unemployed pensioner  0.860836
#
# [1600 rows x 14 columns]

# %%
data.isna().sum()
# Out:
# id                     0
# sex                    0
# age                    0
# federal_district       0
# type_of_city           0
# knows_election_date    0
# will_vote              0
# candidate              0
# television_usage       0
# internet_usage         0
# education              0
# income                 0
# employment             0
# weight1                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   object
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  weight1              1600 non-null   float64
# dtypes: float64(2), object(12)
# memory usage: 175.1+ KB

# %%
data
# Out:
#                     id     sex   age federal_district  \
# 0     07169ed8148ce047    male  18.0  north caucasian
# 1     0716a4f3354cecdd    male  23.0  north caucasian
# 2     0716889b304ce79c    male  20.0            volga
# 3     07168e28b5cce563    male  22.0     northwestern
# 4     0716a563914ce549    male  21.0         southern
# ...                ...     ...   ...              ...
# 1595  0716b23c2c0cee3a    male  61.0          central
# 1596  07168254d14ceb55  female  80.0            volga
# 1597  071690f34d4ce164  female  76.0     northwestern
# 1598  0716bfa9c48ce79a  female  74.0          central
# 1599  07168088318cef88  female  76.0             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# 3     city with population of 1 million and higher  not sure or no answer
# 4     city with population of 1 million and higher     named correct date
# ...                                            ...                    ...
# 1595                                    settlement     named correct date
# 1596                                       village     named correct date
# 1597               city with population of 50-100k     named correct date
# 1598         city with population of less than 50k  not sure or no answer
# 1599                                       village     named correct date
#
#            will_vote           candidate      television_usage  \
# 0           not sure               Putin  several times a week
# 1           not sure               Putin      once half a year
# 2     definitely yes               Putin  several times a week
# 3           not sure            Davankov  several times a week
# 4     definitely yes               Putin        does not watch
# ...              ...                 ...                   ...
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# 1597  definitely yes               Putin        does not watch
# 1598  definitely yes               Putin    over 4 hours a day
# 1599  definitely yes               Putin    over 4 hours a day
#
#                internet_usage                    education       income  \
# 0          over 4 hours a day  incomplete school education    very high
# 1          over 4 hours a day                      college    very high
# 2          over 4 hours a day                      college    very high
# 3          over 4 hours a day                      college    very high
# 4          over 4 hours a day              bachelor degree    very high
# ...                       ...                          ...          ...
# 1595  less than 4 hours a day              bachelor degree  hard to say
# 1596    does not use internet                      college  hard to say
# 1597       over 4 hours a day              bachelor degree  hard to say
# 1598       over 4 hours a day              academic degree  hard to say
# 1599       over 4 hours a day                       school  hard to say
#
#                 employment   weight1
# 0             entrepreneur  1.445172
# 1            work for hire  1.445172
# 2            work for hire  1.301691
# 3               unemployed  1.538628
# 4         employed student  1.967015
# ...                    ...       ...
# 1595  unemployed pensioner  1.270761
# 1596  unemployed pensioner  0.921724
# 1597  unemployed pensioner  1.396691
# 1598    employed pensioner  0.995849
# 1599  unemployed pensioner  0.860836
#
# [1600 rows x 14 columns]

# %% [markdown]
# # Improving Sex Column

# %%
data.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.sex = data.sex.apply(lambda x: 1 if x == 'male' else 0)

# %%
data.sex = data.sex.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   int64
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  weight1              1600 non-null   float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 175.1+ KB

# %% [markdown]
# # Checking other columns now

# %%
data.federal_district.unique()
# Out:
# array(['north caucasian', 'volga', 'northwestern', 'southern', 'central',
#        'ural', 'siberian', 'far eastern'], dtype=object)

# %%
data.type_of_city.unique()
# Out:
# array(['village', 'city with population of less than 50k',
#        'city with population of 1 million and higher',
#        'city with population of 50-100k',
#        'city with population of 100-500k', 'settlement',
#        'city with population of 500-950k'], dtype=object)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='type_of_city', data=data, order=data['type_of_city'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Distribution of City Types')
plt.xlabel('Type of City')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='federal_district', data=data, order=data['federal_district'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Distribution of Federal District')
plt.xlabel('Federal District')
plt.ylabel('Count')
plt.show()

# %%
data
# Out:
#                     id  sex   age federal_district  \
# 0     07169ed8148ce047    1  18.0  north caucasian
# 1     0716a4f3354cecdd    1  23.0  north caucasian
# 2     0716889b304ce79c    1  20.0            volga
# 3     07168e28b5cce563    1  22.0     northwestern
# 4     0716a563914ce549    1  21.0         southern
# ...                ...  ...   ...              ...
# 1595  0716b23c2c0cee3a    1  61.0          central
# 1596  07168254d14ceb55    0  80.0            volga
# 1597  071690f34d4ce164    0  76.0     northwestern
# 1598  0716bfa9c48ce79a    0  74.0          central
# 1599  07168088318cef88    0  76.0             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# 3     city with population of 1 million and higher  not sure or no answer
# 4     city with population of 1 million and higher     named correct date
# ...                                            ...                    ...
# 1595                                    settlement     named correct date
# 1596                                       village     named correct date
# 1597               city with population of 50-100k     named correct date
# 1598         city with population of less than 50k  not sure or no answer
# 1599                                       village     named correct date
#
#            will_vote           candidate      television_usage  \
# 0           not sure               Putin  several times a week
# 1           not sure               Putin      once half a year
# 2     definitely yes               Putin  several times a week
# 3           not sure            Davankov  several times a week
# 4     definitely yes               Putin        does not watch
# ...              ...                 ...                   ...
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# 1597  definitely yes               Putin        does not watch
# 1598  definitely yes               Putin    over 4 hours a day
# 1599  definitely yes               Putin    over 4 hours a day
#
#                internet_usage                    education       income  \
# 0          over 4 hours a day  incomplete school education    very high
# 1          over 4 hours a day                      college    very high
# 2          over 4 hours a day                      college    very high
# 3          over 4 hours a day                      college    very high
# 4          over 4 hours a day              bachelor degree    very high
# ...                       ...                          ...          ...
# 1595  less than 4 hours a day              bachelor degree  hard to say
# 1596    does not use internet                      college  hard to say
# 1597       over 4 hours a day              bachelor degree  hard to say
# 1598       over 4 hours a day              academic degree  hard to say
# 1599       over 4 hours a day                       school  hard to say
#
#                 employment   weight1
# 0             entrepreneur  1.445172
# 1            work for hire  1.445172
# 2            work for hire  1.301691
# 3               unemployed  1.538628
# 4         employed student  1.967015
# ...                    ...       ...
# 1595  unemployed pensioner  1.270761
# 1596  unemployed pensioner  0.921724
# 1597  unemployed pensioner  1.396691
# 1598    employed pensioner  0.995849
# 1599  unemployed pensioner  0.860836
#
# [1600 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   int64
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  weight1              1600 non-null   float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 175.1+ KB

# %% [markdown]
#  # Improving KnowsElectionData Column

# %%
data.knows_election_date.unique()
# Out:
# array(['named correct date', 'not sure or no answer', 'wrong answer',
#        'named correct year'], dtype=object)

# %%
data.knows_election_date = data.knows_election_date.apply(lambda x: 1 if x == "named correct date" else 0)

# %%
data.knows_election_date = data.knows_election_date.astype(int)

# %%
data
# Out:
#                     id  sex   age federal_district  \
# 0     07169ed8148ce047    1  18.0  north caucasian
# 1     0716a4f3354cecdd    1  23.0  north caucasian
# 2     0716889b304ce79c    1  20.0            volga
# 3     07168e28b5cce563    1  22.0     northwestern
# 4     0716a563914ce549    1  21.0         southern
# ...                ...  ...   ...              ...
# 1595  0716b23c2c0cee3a    1  61.0          central
# 1596  07168254d14ceb55    0  80.0            volga
# 1597  071690f34d4ce164    0  76.0     northwestern
# 1598  0716bfa9c48ce79a    0  74.0          central
# 1599  07168088318cef88    0  76.0             ural
#
#                                       type_of_city  knows_election_date  \
# 0                                          village                    1
# 1                                          village                    1
# 2            city with population of less than 50k                    1
# 3     city with population of 1 million and higher                    0
# 4     city with population of 1 million and higher                    1
# ...                                            ...                  ...
# 1595                                    settlement                    1
# 1596                                       village                    1
# 1597               city with population of 50-100k                    1
# 1598         city with population of less than 50k                    0
# 1599                                       village                    1
#
#            will_vote           candidate      television_usage  \
# 0           not sure               Putin  several times a week
# 1           not sure               Putin      once half a year
# 2     definitely yes               Putin  several times a week
# 3           not sure            Davankov  several times a week
# 4     definitely yes               Putin        does not watch
# ...              ...                 ...                   ...
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# 1597  definitely yes               Putin        does not watch
# 1598  definitely yes               Putin    over 4 hours a day
# 1599  definitely yes               Putin    over 4 hours a day
#
#                internet_usage                    education       income  \
# 0          over 4 hours a day  incomplete school education    very high
# 1          over 4 hours a day                      college    very high
# 2          over 4 hours a day                      college    very high
# 3          over 4 hours a day                      college    very high
# 4          over 4 hours a day              bachelor degree    very high
# ...                       ...                          ...          ...
# 1595  less than 4 hours a day              bachelor degree  hard to say
# 1596    does not use internet                      college  hard to say
# 1597       over 4 hours a day              bachelor degree  hard to say
# 1598       over 4 hours a day              academic degree  hard to say
# 1599       over 4 hours a day                       school  hard to say
#
#                 employment   weight1
# 0             entrepreneur  1.445172
# 1            work for hire  1.445172
# 2            work for hire  1.301691
# 3               unemployed  1.538628
# 4         employed student  1.967015
# ...                    ...       ...
# 1595  unemployed pensioner  1.270761
# 1596  unemployed pensioner  0.921724
# 1597  unemployed pensioner  1.396691
# 1598    employed pensioner  0.995849
# 1599  unemployed pensioner  0.860836
#
# [1600 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   int64
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   int64
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  weight1              1600 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 175.1+ KB

# %% [markdown]
# # Improving WillVote column

# %%
data.will_vote.unique()
# Out:
# array(['not sure', 'definitely yes', 'likely no', 'definitely no',
#        'likely yes', 'struggle to answer'], dtype=object)

# %%
data.will_vote = data.will_vote.apply(lambda x: 1 if x == 'definitely yes' or x == 'likely yes' else 0 )

# %%
data.will_vote = data.will_vote.astype(int)

# %%
data
# Out:
#                     id  sex   age federal_district  \
# 0     07169ed8148ce047    1  18.0  north caucasian
# 1     0716a4f3354cecdd    1  23.0  north caucasian
# 2     0716889b304ce79c    1  20.0            volga
# 3     07168e28b5cce563    1  22.0     northwestern
# 4     0716a563914ce549    1  21.0         southern
# ...                ...  ...   ...              ...
# 1595  0716b23c2c0cee3a    1  61.0          central
# 1596  07168254d14ceb55    0  80.0            volga
# 1597  071690f34d4ce164    0  76.0     northwestern
# 1598  0716bfa9c48ce79a    0  74.0          central
# 1599  07168088318cef88    0  76.0             ural
#
#                                       type_of_city  knows_election_date  \
# 0                                          village                    1
# 1                                          village                    1
# 2            city with population of less than 50k                    1
# 3     city with population of 1 million and higher                    0
# 4     city with population of 1 million and higher                    1
# ...                                            ...                  ...
# 1595                                    settlement                    1
# 1596                                       village                    1
# 1597               city with population of 50-100k                    1
# 1598         city with population of less than 50k                    0
# 1599                                       village                    1
#
#       will_vote           candidate      television_usage  \
# 0             0               Putin  several times a week
# 1             0               Putin      once half a year
# 2             1               Putin  several times a week
# 3             0            Davankov  several times a week
# 4             1               Putin        does not watch
# ...         ...                 ...                   ...
# 1595          0  will not take part    over 4 hours a day
# 1596          1  struggle to answer  several times a week
# 1597          1               Putin        does not watch
# 1598          1               Putin    over 4 hours a day
# 1599          1               Putin    over 4 hours a day
#
#                internet_usage                    education       income  \
# 0          over 4 hours a day  incomplete school education    very high
# 1          over 4 hours a day                      college    very high
# 2          over 4 hours a day                      college    very high
# 3          over 4 hours a day                      college    very high
# 4          over 4 hours a day              bachelor degree    very high
# ...                       ...                          ...          ...
# 1595  less than 4 hours a day              bachelor degree  hard to say
# 1596    does not use internet                      college  hard to say
# 1597       over 4 hours a day              bachelor degree  hard to say
# 1598       over 4 hours a day              academic degree  hard to say
# 1599       over 4 hours a day                       school  hard to say
#
#                 employment   weight1
# 0             entrepreneur  1.445172
# 1            work for hire  1.445172
# 2            work for hire  1.301691
# 3               unemployed  1.538628
# 4         employed student  1.967015
# ...                    ...       ...
# 1595  unemployed pensioner  1.270761
# 1596  unemployed pensioner  0.921724
# 1597  unemployed pensioner  1.396691
# 1598    employed pensioner  0.995849
# 1599  unemployed pensioner  0.860836
#
# [1600 rows x 14 columns]

# %%
data.info("")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   int64
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   int64
#  6   will_vote            1600 non-null   int64
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  weight1              1600 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 175.1+ KB

# %% [markdown]
# # Improving Candidate Column

# %%
data.candidate.value_counts()
# Out:
# candidate
# Putin                 1128
# struggle to answer     164
# will not take part      96
# Davankov                67
# Kharitonov              63
# Slutskiy                55
# spoilt vote             27
# Name: count, dtype: int64

# %%
data['candidate'] = data['candidate'].str.strip().str.lower()

# %%
# Performing OHE
encoded_candidates = pd.get_dummies(data['candidate'], prefix='candidate')

# %%
encoded_candidates
# Out:
#       candidate_davankov  candidate_kharitonov  candidate_putin  \
# 0                  False                 False             True
# 1                  False                 False             True
# 2                  False                 False             True
# 3                   True                 False            False
# 4                  False                 False             True
# ...                  ...                   ...              ...
# 1595               False                 False            False
# 1596               False                 False            False
# 1597               False                 False             True
# 1598               False                 False             True
# 1599               False                 False             True
#
#       candidate_slutskiy  candidate_spoilt vote  candidate_struggle to answer  \
# 0                  False                  False                         False
# 1                  False                  False                         False
# 2                  False                  False                         False
# 3                  False                  False                         False
# 4                  False                  False                         False
# ...                  ...                    ...                           ...
# 1595               False                  False                         False
# 1596               False                  False                          True
# 1597               False                  False                         False
# 1598               False                  False                         False
# 1599               False                  False                         False
#
#       candidate_will not take part
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# 1595                          True
# 1596                         False
# 1597                         False
# 1598                         False
# 1599                         False
#
# [1600 rows x 7 columns]

# %%
data = pd.concat([data, encoded_candidates], axis=1)

# %%
data.head(5)
# Out:
#                  id  sex   age federal_district  \
# 0  07169ed8148ce047    1  18.0  north caucasian
# 1  0716a4f3354cecdd    1  23.0  north caucasian
# 2  0716889b304ce79c    1  20.0            volga
# 3  07168e28b5cce563    1  22.0     northwestern
# 4  0716a563914ce549    1  21.0         southern
#
#                                    type_of_city  knows_election_date  \
# 0                                       village                    1
# 1                                       village                    1
# 2         city with population of less than 50k                    1
# 3  city with population of 1 million and higher                    0
# 4  city with population of 1 million and higher                    1
#
#    will_vote candidate      television_usage      internet_usage  ...  \
# 0          0     putin  several times a week  over 4 hours a day  ...
# 1          0     putin      once half a year  over 4 hours a day  ...
# 2          1     putin  several times a week  over 4 hours a day  ...
# 3          0  davankov  several times a week  over 4 hours a day  ...
# 4          1     putin        does not watch  over 4 hours a day  ...
#
#       income        employment   weight1  candidate_davankov  \
# 0  very high      entrepreneur  1.445172               False
# 1  very high     work for hire  1.445172               False
# 2  very high     work for hire  1.301691               False
# 3  very high        unemployed  1.538628                True
# 4  very high  employed student  1.967015               False
#
#    candidate_kharitonov  candidate_putin  candidate_slutskiy  \
# 0                 False             True               False
# 1                 False             True               False
# 2                 False             True               False
# 3                 False            False               False
# 4                 False             True               False
#
#    candidate_spoilt vote  candidate_struggle to answer  \
# 0                  False                         False
# 1                  False                         False
# 2                  False                         False
# 3                  False                         False
# 4                  False                         False
#
#    candidate_will not take part
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
#
# [5 rows x 21 columns]

# %%
data.drop('candidate', axis=1, inplace=True)

# %%
data
# Out:
#                     id  sex   age federal_district  \
# 0     07169ed8148ce047    1  18.0  north caucasian
# 1     0716a4f3354cecdd    1  23.0  north caucasian
# 2     0716889b304ce79c    1  20.0            volga
# 3     07168e28b5cce563    1  22.0     northwestern
# 4     0716a563914ce549    1  21.0         southern
# ...                ...  ...   ...              ...
# 1595  0716b23c2c0cee3a    1  61.0          central
# 1596  07168254d14ceb55    0  80.0            volga
# 1597  071690f34d4ce164    0  76.0     northwestern
# 1598  0716bfa9c48ce79a    0  74.0          central
# 1599  07168088318cef88    0  76.0             ural
#
#                                       type_of_city  knows_election_date  \
# 0                                          village                    1
# 1                                          village                    1
# 2            city with population of less than 50k                    1
# 3     city with population of 1 million and higher                    0
# 4     city with population of 1 million and higher                    1
# ...                                            ...                  ...
# 1595                                    settlement                    1
# 1596                                       village                    1
# 1597               city with population of 50-100k                    1
# 1598         city with population of less than 50k                    0
# 1599                                       village                    1
#
#       will_vote      television_usage           internet_usage  \
# 0             0  several times a week       over 4 hours a day
# 1             0      once half a year       over 4 hours a day
# 2             1  several times a week       over 4 hours a day
# 3             0  several times a week       over 4 hours a day
# 4             1        does not watch       over 4 hours a day
# ...         ...                   ...                      ...
# 1595          0    over 4 hours a day  less than 4 hours a day
# 1596          1  several times a week    does not use internet
# 1597          1        does not watch       over 4 hours a day
# 1598          1    over 4 hours a day       over 4 hours a day
# 1599          1    over 4 hours a day       over 4 hours a day
#
#                         education       income            employment  \
# 0     incomplete school education    very high          entrepreneur
# 1                         college    very high         work for hire
# 2                         college    very high         work for hire
# 3                         college    very high            unemployed
# 4                 bachelor degree    very high      employed student
# ...                           ...          ...                   ...
# 1595              bachelor degree  hard to say  unemployed pensioner
# 1596                      college  hard to say  unemployed pensioner
# 1597              bachelor degree  hard to say  unemployed pensioner
# 1598              academic degree  hard to say    employed pensioner
# 1599                       school  hard to say  unemployed pensioner
#
#        weight1  candidate_davankov  candidate_kharitonov  candidate_putin  \
# 0     1.445172               False                 False             True
# 1     1.445172               False                 False             True
# 2     1.301691               False                 False             True
# 3     1.538628                True                 False            False
# 4     1.967015               False                 False             True
# ...        ...                 ...                   ...              ...
# 1595  1.270761               False                 False            False
# 1596  0.921724               False                 False            False
# 1597  1.396691               False                 False             True
# 1598  0.995849               False                 False             True
# 1599  0.860836               False                 False             True
#
#       candidate_slutskiy  candidate_spoilt vote  candidate_struggle to answer  \
# 0                  False                  False                         False
# 1                  False                  False                         False
# 2                  False                  False                         False
# 3                  False                  False                         False
# 4                  False                  False                         False
# ...                  ...                    ...                           ...
# 1595               False                  False                         False
# 1596               False                  False                          True
# 1597               False                  False                         False
# 1598               False                  False                         False
# 1599               False                  False                         False
#
#       candidate_will not take part
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# 1595                          True
# 1596                         False
# 1597                         False
# 1598                         False
# 1599                         False
#
# [1600 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1600 non-null   object
#  1   sex                           1600 non-null   int64
#  2   age                           1600 non-null   float64
#  3   federal_district              1600 non-null   object
#  4   type_of_city                  1600 non-null   object
#  5   knows_election_date           1600 non-null   int64
#  6   will_vote                     1600 non-null   int64
#  7   television_usage              1600 non-null   object
#  8   internet_usage                1600 non-null   object
#  9   education                     1600 non-null   object
#  10  income                        1600 non-null   object
#  11  employment                    1600 non-null   object
#  12  weight1                       1600 non-null   float64
#  13  candidate_davankov            1600 non-null   bool
#  14  candidate_kharitonov          1600 non-null   bool
#  15  candidate_putin               1600 non-null   bool
#  16  candidate_slutskiy            1600 non-null   bool
#  17  candidate_spoilt vote         1600 non-null   bool
#  18  candidate_struggle to answer  1600 non-null   bool
#  19  candidate_will not take part  1600 non-null   bool
# dtypes: bool(7), float64(2), int64(3), object(8)
# memory usage: 173.6+ KB

# %% [markdown]
# # Checking for TV Usage

# %%
data.television_usage.value_counts()
# Out:
# television_usage
# less than 4 hours a day    490
# over 4 hours a day         436
# does not watch             332
# several times a week       204
# several times a month       76
# once half a year            62
# Name: count, dtype: int64

# %%
# Performing OHE
encoded_tv_usage = pd.get_dummies(data['television_usage'], prefix='tv_usage')

# %%
data = pd.concat([data, encoded_tv_usage], axis=1)
data.drop('television_usage', axis=1, inplace=True)
data
# Out:
#                     id  sex   age federal_district  \
# 0     07169ed8148ce047    1  18.0  north caucasian
# 1     0716a4f3354cecdd    1  23.0  north caucasian
# 2     0716889b304ce79c    1  20.0            volga
# 3     07168e28b5cce563    1  22.0     northwestern
# 4     0716a563914ce549    1  21.0         southern
# ...                ...  ...   ...              ...
# 1595  0716b23c2c0cee3a    1  61.0          central
# 1596  07168254d14ceb55    0  80.0            volga
# 1597  071690f34d4ce164    0  76.0     northwestern
# 1598  0716bfa9c48ce79a    0  74.0          central
# 1599  07168088318cef88    0  76.0             ural
#
#                                       type_of_city  knows_election_date  \
# 0                                          village                    1
# 1                                          village                    1
# 2            city with population of less than 50k                    1
# 3     city with population of 1 million and higher                    0
# 4     city with population of 1 million and higher                    1
# ...                                            ...                  ...
# 1595                                    settlement                    1
# 1596                                       village                    1
# 1597               city with population of 50-100k                    1
# 1598         city with population of less than 50k                    0
# 1599                                       village                    1
#
#       will_vote           internet_usage                    education  \
# 0             0       over 4 hours a day  incomplete school education
# 1             0       over 4 hours a day                      college
# 2             1       over 4 hours a day                      college
# 3             0       over 4 hours a day                      college
# 4             1       over 4 hours a day              bachelor degree
# ...         ...                      ...                          ...
# 1595          0  less than 4 hours a day              bachelor degree
# 1596          1    does not use internet                      college
# 1597          1       over 4 hours a day              bachelor degree
# 1598          1       over 4 hours a day              academic degree
# 1599          1       over 4 hours a day                       school
#
#            income  ...  tv_usage_once half a year  \
# 0       very high  ...                      False
# 1       very high  ...                       True
# 2       very high  ...                      False
# 3       very high  ...                      False
# 4       very high  ...                      False
# ...           ...  ...                        ...
# 1595  hard to say  ...                      False
# 1596  hard to say  ...                      False
# 1597  hard to say  ...                      False
# 1598  hard to say  ...                      False
# 1599  hard to say  ...                      False
#
#       tv_usage_over 4 hours a day  tv_usage_several times a month  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# ...                           ...                             ...
# 1595                         True                           False
# 1596                        False                           False
# 1597                        False                           False
# 1598                         True                           False
# 1599                         True                           False
#
#       tv_usage_several times a week  tv_usage_does not watch  \
# 0                              True                    False
# 1                             False                    False
# 2                              True                    False
# 3                              True                    False
# 4                             False                     True
# ...                             ...                      ...
# 1595                          False                    False
# 1596                           True                    False
# 1597                          False                     True
# 1598                          False                    False
# 1599                          False                    False
#
#       tv_usage_less than 4 hours a day  tv_usage_once half a year  \
# 0                                False                      False
# 1                                False                       True
# 2                                False                      False
# 3                                False                      False
# 4                                False                      False
# ...                                ...                        ...
# 1595                             False                      False
# 1596                             False                      False
# 1597                             False                      False
# 1598                             False                      False
# 1599                             False                      False
#
#       tv_usage_over 4 hours a day  tv_usage_several times a month  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# ...                           ...                             ...
# 1595                         True                           False
# 1596                        False                           False
# 1597                        False                           False
# 1598                         True                           False
# 1599                         True                           False
#
#       tv_usage_several times a week
# 0                              True
# 1                             False
# 2                              True
# 3                              True
# 4                             False
# ...                             ...
# 1595                          False
# 1596                           True
# 1597                          False
# 1598                          False
# 1599                          False
#
# [1600 rows x 31 columns]

# %% [markdown]
# # Checking for Internet usage

# %%
data.internet_usage.value_counts()
# Out:
# internet_usage
# less than 4 hours a day    613
# over 4 hours a day         576
# does not use internet      259
# several times a week       107
# several times a month       27
# once half a year            18
# Name: count, dtype: int64

# %%
# Performing OHE
encoded_it_usage = pd.get_dummies(data['internet_usage'], prefix='it_usage')

# %%
data = pd.concat([data, encoded_it_usage], axis=1)
data.drop('internet_usage', axis=1, inplace=True)
data
# Out:
#                     id  sex   age federal_district  \
# 0     07169ed8148ce047    1  18.0  north caucasian
# 1     0716a4f3354cecdd    1  23.0  north caucasian
# 2     0716889b304ce79c    1  20.0            volga
# 3     07168e28b5cce563    1  22.0     northwestern
# 4     0716a563914ce549    1  21.0         southern
# ...                ...  ...   ...              ...
# 1595  0716b23c2c0cee3a    1  61.0          central
# 1596  07168254d14ceb55    0  80.0            volga
# 1597  071690f34d4ce164    0  76.0     northwestern
# 1598  0716bfa9c48ce79a    0  74.0          central
# 1599  07168088318cef88    0  76.0             ural
#
#                                       type_of_city  knows_election_date  \
# 0                                          village                    1
# 1                                          village                    1
# 2            city with population of less than 50k                    1
# 3     city with population of 1 million and higher                    0
# 4     city with population of 1 million and higher                    1
# ...                                            ...                  ...
# 1595                                    settlement                    1
# 1596                                       village                    1
# 1597               city with population of 50-100k                    1
# 1598         city with population of less than 50k                    0
# 1599                                       village                    1
#
#       will_vote                    education       income  \
# 0             0  incomplete school education    very high
# 1             0                      college    very high
# 2             1                      college    very high
# 3             0                      college    very high
# 4             1              bachelor degree    very high
# ...         ...                          ...          ...
# 1595          0              bachelor degree  hard to say
# 1596          1                      college  hard to say
# 1597          1              bachelor degree  hard to say
# 1598          1              academic degree  hard to say
# 1599          1                       school  hard to say
#
#                 employment  ...  tv_usage_once half a year  \
# 0             entrepreneur  ...                      False
# 1            work for hire  ...                       True
# 2            work for hire  ...                      False
# 3               unemployed  ...                      False
# 4         employed student  ...                      False
# ...                    ...  ...                        ...
# 1595  unemployed pensioner  ...                      False
# 1596  unemployed pensioner  ...                      False
# 1597  unemployed pensioner  ...                      False
# 1598    employed pensioner  ...                      False
# 1599  unemployed pensioner  ...                      False
#
#       tv_usage_over 4 hours a day  tv_usage_several times a month  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# ...                           ...                             ...
# 1595                         True                           False
# 1596                        False                           False
# 1597                        False                           False
# 1598                         True                           False
# 1599                         True                           False
#
#       tv_usage_several times a week  it_usage_does not use internet  \
# 0                              True                           False
# 1                             False                           False
# 2                              True                           False
# 3                              True                           False
# 4                             False                           False
# ...                             ...                             ...
# 1595                          False                           False
# 1596                           True                            True
# 1597                          False                           False
# 1598                          False                           False
# 1599                          False                           False
#
#       it_usage_less than 4 hours a day  it_usage_once half a year  \
# 0                                False                      False
# 1                                False                      False
# 2                                False                      False
# 3                                False                      False
# 4                                False                      False
# ...                                ...                        ...
# 1595                              True                      False
# 1596                             False                      False
# 1597                             False                      False
# 1598                             False                      False
# 1599                             False                      False
#
#       it_usage_over 4 hours a day  it_usage_several times a month  \
# 0                            True                           False
# 1                            True                           False
# 2                            True                           False
# 3                            True                           False
# 4                            True                           False
# ...                           ...                             ...
# 1595                        False                           False
# 1596                        False                           False
# 1597                         True                           False
# 1598                         True                           False
# 1599                         True                           False
#
#       it_usage_several times a week
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
# ...                             ...
# 1595                          False
# 1596                          False
# 1597                          False
# 1598                          False
# 1599                          False
#
# [1600 rows x 36 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1600 non-null   object
#  1   sex                               1600 non-null   int64
#  2   age                               1600 non-null   float64
#  3   federal_district                  1600 non-null   object
#  4   type_of_city                      1600 non-null   object
#  5   knows_election_date               1600 non-null   int64
#  6   will_vote                         1600 non-null   int64
#  7   education                         1600 non-null   object
#  8   income                            1600 non-null   object
#  9   employment                        1600 non-null   object
#  10  weight1                           1600 non-null   float64
#  11  candidate_davankov                1600 non-null   bool
#  12  candidate_kharitonov              1600 non-null   bool
#  13  candidate_putin                   1600 non-null   bool
#  14  candidate_slutskiy                1600 non-null   bool
#  15  candidate_spoilt vote             1600 non-null   bool
#  16  candidate_struggle to answer      1600 non-null   bool
#  17  candidate_will not take part      1600 non-null   bool
#  18  tv_usage_does not watch           1600 non-null   bool
#  19  tv_usage_less than 4 hours a day  1600 non-null   bool
#  20  tv_usage_once half a year         1600 non-null   bool
#  21  tv_usage_over 4 hours a day       1600 non-null   bool
#  22  tv_usage_several times a month    1600 non-null   bool
#  23  tv_usage_several times a week     1600 non-null   bool
#  24  tv_usage_does not watch           1600 non-null   bool
#  25  tv_usage_less than 4 hours a day  1600 non-null   bool
#  26  tv_usage_once half a year         1600 non-null   bool
#  27  tv_usage_over 4 hours a day       1600 non-null   bool
#  28  tv_usage_several times a month    1600 non-null   bool
#  29  tv_usage_several times a week     1600 non-null   bool
#  30  it_usage_does not use internet    1600 non-null   bool
#  31  it_usage_less than 4 hours a day  1600 non-null   bool
#  32  it_usage_once half a year         1600 non-null   bool
#  33  it_usage_over 4 hours a day       1600 non-null   bool
#  34  it_usage_several times a month    1600 non-null   bool
#  35  it_usage_several times a week     1600 non-null   bool
# dtypes: bool(25), float64(2), int64(3), object(6)
# memory usage: 176.7+ KB

# %%
data.education.unique()
# Out:
# array(['incomplete school education', 'college', 'bachelor degree',
#        'school', 'academic degree', 'no school education'], dtype=object)

# %%
data.income.unique()
# Out:
# array(['very high', 'high', 'medium', 'low', 'very low', 'hard to say'],
#       dtype=object)

# %%
data.employment.unique()
# Out:
# array(['entrepreneur', 'work for hire', 'unemployed', 'employed student',
#        'self-employed', 'unemployed pensioner', 'employed pensioner',
#        'unemployed student', 'parental leave', 'hard to say',
#        'refused to answer'], dtype=object)

# %%
encoded_education = pd.get_dummies(data['education'], prefix='education')
data = pd.concat([data, encoded_education], axis=1)
data.drop('education', axis=1, inplace=True)

encoded_inc = pd.get_dummies(data['income'], prefix='income')
data = pd.concat([data, encoded_inc], axis=1)
data.drop('income', axis=1, inplace=True)

encoded_emp = pd.get_dummies(data['employment'], prefix='employment')
data = pd.concat([data, encoded_emp], axis=1)
data.drop('employment', axis=1, inplace=True)

# %%
data
# Out:
#                     id  sex   age federal_district  \
# 0     07169ed8148ce047    1  18.0  north caucasian
# 1     0716a4f3354cecdd    1  23.0  north caucasian
# 2     0716889b304ce79c    1  20.0            volga
# 3     07168e28b5cce563    1  22.0     northwestern
# 4     0716a563914ce549    1  21.0         southern
# ...                ...  ...   ...              ...
# 1595  0716b23c2c0cee3a    1  61.0          central
# 1596  07168254d14ceb55    0  80.0            volga
# 1597  071690f34d4ce164    0  76.0     northwestern
# 1598  0716bfa9c48ce79a    0  74.0          central
# 1599  07168088318cef88    0  76.0             ural
#
#                                       type_of_city  knows_election_date  \
# 0                                          village                    1
# 1                                          village                    1
# 2            city with population of less than 50k                    1
# 3     city with population of 1 million and higher                    0
# 4     city with population of 1 million and higher                    1
# ...                                            ...                  ...
# 1595                                    settlement                    1
# 1596                                       village                    1
# 1597               city with population of 50-100k                    1
# 1598         city with population of less than 50k                    0
# 1599                                       village                    1
#
#       will_vote   weight1  candidate_davankov  candidate_kharitonov  ...  \
# 0             0  1.445172               False                 False  ...
# 1             0  1.445172               False                 False  ...
# 2             1  1.301691               False                 False  ...
# 3             0  1.538628                True                 False  ...
# 4             1  1.967015               False                 False  ...
# ...         ...       ...                 ...                   ...  ...
# 1595          0  1.270761               False                 False  ...
# 1596          1  0.921724               False                 False  ...
# 1597          1  1.396691               False                 False  ...
# 1598          1  0.995849               False                 False  ...
# 1599          1  0.860836               False                 False  ...
#
#       employment_employed student  employment_entrepreneur  \
# 0                           False                     True
# 1                           False                    False
# 2                           False                    False
# 3                           False                    False
# 4                            True                    False
# ...                           ...                      ...
# 1595                        False                    False
# 1596                        False                    False
# 1597                        False                    False
# 1598                        False                    False
# 1599                        False                    False
#
#       employment_hard to say  employment_parental leave  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
# ...                      ...                        ...
# 1595                   False                      False
# 1596                   False                      False
# 1597                   False                      False
# 1598                   False                      False
# 1599                   False                      False
#
#       employment_refused to answer  employment_self-employed  \
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# 3                            False                     False
# 4                            False                     False
# ...                            ...                       ...
# 1595                         False                     False
# 1596                         False                     False
# 1597                         False                     False
# 1598                         False                     False
# 1599                         False                     False
#
#       employment_unemployed  employment_unemployed pensioner  \
# 0                     False                            False
# 1                     False                            False
# 2                     False                            False
# 3                      True                            False
# 4                     False                            False
# ...                     ...                              ...
# 1595                  False                             True
# 1596                  False                             True
# 1597                  False                             True
# 1598                  False                            False
# 1599                  False                             True
#
#       employment_unemployed student  employment_work for hire
# 0                             False                     False
# 1                             False                      True
# 2                             False                      True
# 3                             False                     False
# 4                             False                     False
# ...                             ...                       ...
# 1595                          False                     False
# 1596                          False                     False
# 1597                          False                     False
# 1598                          False                     False
# 1599                          False                     False
#
# [1600 rows x 56 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 56 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     1600 non-null   object
#  1   sex                                    1600 non-null   int64
#  2   age                                    1600 non-null   float64
#  3   federal_district                       1600 non-null   object
#  4   type_of_city                           1600 non-null   object
#  5   knows_election_date                    1600 non-null   int64
#  6   will_vote                              1600 non-null   int64
#  7   weight1                                1600 non-null   float64
#  8   candidate_davankov                     1600 non-null   bool
#  9   candidate_kharitonov                   1600 non-null   bool
#  10  candidate_putin                        1600 non-null   bool
#  11  candidate_slutskiy                     1600 non-null   bool
#  12  candidate_spoilt vote                  1600 non-null   bool
#  13  candidate_struggle to answer           1600 non-null   bool
#  14  candidate_will not take part           1600 non-null   bool
#  15  tv_usage_does not watch                1600 non-null   bool
#  16  tv_usage_less than 4 hours a day       1600 non-null   bool
#  17  tv_usage_once half a year              1600 non-null   bool
#  18  tv_usage_over 4 hours a day            1600 non-null   bool
#  19  tv_usage_several times a month         1600 non-null   bool
#  20  tv_usage_several times a week          1600 non-null   bool
#  21  tv_usage_does not watch                1600 non-null   bool
#  22  tv_usage_less than 4 hours a day       1600 non-null   bool
#  23  tv_usage_once half a year              1600 non-null   bool
#  24  tv_usage_over 4 hours a day            1600 non-null   bool
#  25  tv_usage_several times a month         1600 non-null   bool
#  26  tv_usage_several times a week          1600 non-null   bool
#  27  it_usage_does not use internet         1600 non-null   bool
#  28  it_usage_less than 4 hours a day       1600 non-null   bool
#  29  it_usage_once half a year              1600 non-null   bool
#  30  it_usage_over 4 hours a day            1600 non-null   bool
#  31  it_usage_several times a month         1600 non-null   bool
#  32  it_usage_several times a week          1600 non-null   bool
#  33  education_academic degree              1600 non-null   bool
#  34  education_bachelor degree              1600 non-null   bool
#  35  education_college                      1600 non-null   bool
#  36  education_incomplete school education  1600 non-null   bool
#  37  education_no school education          1600 non-null   bool
#  38  education_school                       1600 non-null   bool
#  39  income_hard to say                     1600 non-null   bool
#  40  income_high                            1600 non-null   bool
#  41  income_low                             1600 non-null   bool
#  42  income_medium                          1600 non-null   bool
#  43  income_very high                       1600 non-null   bool
#  44  income_very low                        1600 non-null   bool
#  45  employment_employed pensioner          1600 non-null   bool
#  46  employment_employed student            1600 non-null   bool
#  47  employment_entrepreneur                1600 non-null   bool
#  48  employment_hard to say                 1600 non-null   bool
#  49  employment_parental leave              1600 non-null   bool
#  50  employment_refused to answer           1600 non-null   bool
#  51  employment_self-employed               1600 non-null   bool
#  52  employment_unemployed                  1600 non-null   bool
#  53  employment_unemployed pensioner        1600 non-null   bool
#  54  employment_unemployed student          1600 non-null   bool
#  55  employment_work for hire               1600 non-null   bool
# dtypes: bool(48), float64(2), int64(3), object(3)
# memory usage: 175.1+ KB
